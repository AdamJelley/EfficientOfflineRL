# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()
plt.rcParams["lines.linewidth"] = 1.5

# %%
data = pd.read_csv("../data/EDACWalker2d.csv")
data.columns
# Out:
# Index(['Step',
#        'Name: Prod-EDAC-pretrainAC100TD0.5-walker2d-medium - eval/normalized_score_mean',
#        'Name: Prod-EDAC-pretrainAC100TD0.5-walker2d-medium - eval/normalized_score_mean__MIN',
#        'Name: Prod-EDAC-pretrainAC100TD0.5-walker2d-medium - eval/normalized_score_mean__MAX',
#        'Name: Prod-EDAC-pretrainBC50-walker2d-medium - eval/normalized_score_mean',
#        'Name: Prod-EDAC-pretrainBC50-walker2d-medium - eval/normalized_score_mean__MIN',
#        'Name: Prod-EDAC-pretrainBC50-walker2d-medium - eval/normalized_score_mean__MAX',
#        'Name: Prod-EDAC-noLN-walker2d-medium - eval/normalized_score_mean',
#        'Name: Prod-EDAC-noLN-walker2d-medium - eval/normalized_score_mean__MIN',
#        'Name: Prod-EDAC-noLN-walker2d-medium - eval/normalized_score_mean__MAX',
#        'Name: Prod-EDAC-walker2d-medium - eval/normalized_score_mean',
#        'Name: Prod-EDAC-walker2d-medium - eval/normalized_score_mean__MIN',
# ...

# %%
# data = data[data["Step"] < 3001]
data["Step"] = data["Step"] * 100 / 100000

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 4))
ax.plot(
    data["Step"],
    53 * np.ones_like(data["Step"]),
    label="Behaviour Cloning Performance",
    linestyle="--",
    color="k",
    linewidth=1.0,
)
ax.plot(
    data["Step"],
    data["Name: Prod-EDAC-noLN-walker2d-medium - eval/normalized_score_mean"],
    label="No LayerNorm or Pretraining",
    color="tab:green",
)
ax.fill_between(
    data["Step"],
    data["Name: Prod-EDAC-noLN-walker2d-medium - eval/normalized_score_mean"]
    - (
        data["Name: Prod-EDAC-noLN-walker2d-medium - eval/normalized_score_mean__MAX"]
        - data["Name: Prod-EDAC-noLN-walker2d-medium - eval/normalized_score_mean__MIN"]
    )
    / 4,
    data["Name: Prod-EDAC-noLN-walker2d-medium - eval/normalized_score_mean"]
    + (
        data["Name: Prod-EDAC-noLN-walker2d-medium - eval/normalized_score_mean__MAX"]
        - data["Name: Prod-EDAC-noLN-walker2d-medium - eval/normalized_score_mean__MIN"]
    )
    / 4,
    color="tab:green",
    alpha=0.5,
)
ax.plot(
    data["Step"],
    data["Name: Prod-EDAC-walker2d-medium - eval/normalized_score_mean"],
    label="No Pretraining",
    color="k",
)
ax.fill_between(
    data["Step"],
    data["Name: Prod-EDAC-walker2d-medium - eval/normalized_score_mean"]
    - (
        data["Name: Prod-EDAC-walker2d-medium - eval/normalized_score_mean__MAX"]
        - data["Name: Prod-EDAC-walker2d-medium - eval/normalized_score_mean__MIN"]
    )
    / 4,
    data["Name: Prod-EDAC-walker2d-medium - eval/normalized_score_mean"]
    + (
        data["Name: Prod-EDAC-walker2d-medium - eval/normalized_score_mean__MAX"]
        - data["Name: Prod-EDAC-walker2d-medium - eval/normalized_score_mean__MIN"]
    )
    / 4,
    color="k",
    alpha=0.5,
)
ax.plot(
    data["Step"],
    data["Name: Prod-EDAC-pretrainBC50-walker2d-medium - eval/normalized_score_mean"],
    label="Pretrained Actor (Behaviour Cloning)",
    color="tab:red",
)
ax.fill_between(
    data["Step"],
    data["Name: Prod-EDAC-pretrainBC50-walker2d-medium - eval/normalized_score_mean"]
    - (
        data[
            "Name: Prod-EDAC-pretrainBC50-walker2d-medium - eval/normalized_score_mean__MAX"
        ]
        - data[
            "Name: Prod-EDAC-pretrainBC50-walker2d-medium - eval/normalized_score_mean__MIN"
        ]
    )
    / 4,
    data["Name: Prod-EDAC-pretrainBC50-walker2d-medium - eval/normalized_score_mean"]
    + (
        data[
            "Name: Prod-EDAC-pretrainBC50-walker2d-medium - eval/normalized_score_mean__MAX"
        ]
        - data[
            "Name: Prod-EDAC-pretrainBC50-walker2d-medium - eval/normalized_score_mean__MIN"
        ]
    )
    / 4,
    color="tab:red",
    alpha=0.5,
)
ax.plot(
    data["Step"],
    data[
        "Name: Prod-EDAC-pretrainAC100TD0.5-walker2d-medium - eval/normalized_score_mean"
    ],
    label=r"Pretrained Actor+Critic, $\lambda=0.1$ $\bf(Ours)$",
    color="tab:blue",
)
ax.fill_between(
    data["Step"],
    data[
        "Name: Prod-EDAC-pretrainAC100TD0.5-walker2d-medium - eval/normalized_score_mean"
    ]
    - (
        data[
            "Name: Prod-EDAC-pretrainAC100TD0.5-walker2d-medium - eval/normalized_score_mean__MAX"
        ]
        - data[
            "Name: Prod-EDAC-pretrainAC100TD0.5-walker2d-medium - eval/normalized_score_mean__MIN"
        ]
    )
    / 4,
    data[
        "Name: Prod-EDAC-pretrainAC100TD0.5-walker2d-medium - eval/normalized_score_mean"
    ]
    + (
        data[
            "Name: Prod-EDAC-pretrainAC100TD0.5-walker2d-medium - eval/normalized_score_mean__MAX"
        ]
        - data[
            "Name: Prod-EDAC-pretrainAC100TD0.5-walker2d-medium - eval/normalized_score_mean__MIN"
        ]
    )
    / 4,
    color="tab:blue",
    alpha=0.5,
)
ax.axvspan(0, 1.1, alpha=0.5, color="tab:blue", label="Pretraining Phase")
ax.set_xlim(0)
ax.legend(loc="lower right", fontsize=12)
ax.set_title(r"Walker2d-medium - EDAC $(N=10)$", fontsize=20)
ax.set_xlabel("Training Steps (1e5)", fontsize=16)
ax.set_ylabel("Normalised Return", fontsize=16)
ax.grid(visible=True, which="major")
ax.grid(visible=True, which="minor", linewidth=0.3)
ax.minorticks_on()
ax.xaxis.set_major_formatter(matplotlib.ticker.StrMethodFormatter("{x:.1f}"))
plt.show()
fig.savefig("../plots/EDACWalker2d.pdf", bbox_inches="tight")
